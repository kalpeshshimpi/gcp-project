# %%
spark.conf.set("fs.s3a.access.key",dbutils.secrets.get(scope = "s3secrets", key = "access-key"))
spark.conf.set("fs.s3a.secret.key",dbutils.secrets.get(scope = "s3secrets", key = "secret-key"))

# %%
df=spark.read.format("csv").option("inferSchema",True).option("header",True).load("s3://acg-kalpesh-new-bucket/data/patient_data_2025_02_21.csv")
df.show()
